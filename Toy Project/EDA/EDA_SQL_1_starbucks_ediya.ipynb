# %% [markdown]
# # 스타벅스 이디야 원데이 with SQL

# %% [markdown]
# 이디야커피는 스타벅스 커피 매장이 위치하는 곳에 매장을 위치시키는 것인가? >> 검증

# %%
""" For EDA ======================================= """
from selenium import webdriver
from selenium.webdriver.chrome.service import Service
from webdriver_manager.chrome import ChromeDriverManager
from selenium.webdriver.common.by import By
from selenium.webdriver.common.keys import Keys
from selenium.webdriver.support.wait import WebDriverWait
from selenium.webdriver.support import expected_conditions as EC
from selenium.webdriver.common.action_chains import ActionChains

from bs4 import BeautifulSoup

import re

import json
from glob import glob

import time
from tqdm.notebook import tqdm

import folium

import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import koreanize_matplotlib
import plotly.express as px

import warnings
warnings.simplefilter(action="ignore", category=FutureWarning)

""" For SQL ======================================= """
import mysql.connector

# %% [markdown]
# ## 1. 서울시의 스타벅스 매장 정보를 데이터베이스에 저장

# %% [markdown]
# ### flow check

# %%
url = "https://www.starbucks.co.kr/index.do"

driver = webdriver.Chrome(service=Service("../EDA/driver/chromedriver"))
driver.get(url)

driver.maximize_window()
driver.implicitly_wait(3)

if driver is not None:
    print("웹페이지 접속 완료", "\n")
# Out:
# 웹페이지 접속 완료

# %% [markdown]
# - ```store``` 메뉴 > ```매장 찾기```의 ```지역 검색``` 옵션 클릭

# %%
store_menu = driver.find_element(By.CLASS_NAME, "gnb_nav03")
loca_search_option = driver.find_element(By.CSS_SELECTOR, "#gnb > div > nav > div > ul > li.gnb_nav03 > div > div > div > ul:nth-child(1) > li:nth-child(3) > a")

action = ActionChains(driver)
action.move_to_element(store_menu)
action.move_to_element(loca_search_option)
action.click().perform()

# %% [markdown]
# - ```시도``` 옵션 리스트 생성

# %%
wait = WebDriverWait(driver, 5)
sido_box = wait.until(EC.presence_of_element_located((By.CLASS_NAME, "sido_arae_box")))
sido_list = sido_box.find_elements(By.TAG_NAME, "li")

for idx, sido_item in enumerate(sido_list):
    print("%4s"%(str(idx)), sido_item.find_element(By.TAG_NAME, "a").text)
# Out:
#    0 서울
#    1 경기
#    2 광주
#    3 대구
#    4 대전
#    5 부산
#    6 울산
#    7 인천
#    8 강원
#    9 경남
#   10 경북
#   11 전남
#   12 전북
#   13 충남
#   14 충북
#   15 제주
#   16 세종

# %% [markdown]
# - ```서울``` 클릭

# %%
wait = WebDriverWait(sido_list[0], 5)
seoul_option = wait.until(EC.element_to_be_clickable((By.TAG_NAME, "a")))
seoul_option.click()

# %% [markdown]
# - ```구``` 옵션 리스트 생성

# %%
wait = WebDriverWait(driver, 5)
gu_box = wait.until(EC.presence_of_element_located((By.CLASS_NAME, "gugun_arae_box")))
gu_list = gu_box.find_elements(By.TAG_NAME, "li")

for idx, gu_item in enumerate(gu_list):
    print("%4s"%(str(idx)), gu_item.find_element(By.TAG_NAME, "a").get_attribute("innerHTML"))
# Out:
#    0 전체
#    1 강남구
#    2 강동구
#    3 강북구
#    4 강서구
#    5 관악구
#    6 광진구
#    7 구로구
#    8 금천구
#    9 노원구
#   10 도봉구
#   11 동대문구
#   12 동작구
#   13 마포구
#   14 서대문구
#   15 서초구
#   16 성동구
#   17 성북구
#   18 송파구
#   19 양천구
#   20 영등포구
#   21 용산구
#   22 은평구
#   23 종로구
#   24 중구
#   25 중랑구

# %% [markdown]
# - ```전체``` 클릭

# %%
wait = WebDriverWait(gu_list[0], 5)
total_gu_option = wait.until(EC.element_to_be_clickable((By.TAG_NAME, "a")))
total_gu_option.click()

# %% [markdown]
# - ```매장 정보``` 추출
#
# Selenium으로 서울시 전체 스타벅스 매장 검색 결과 출력 작업 수행 완료 후, 해당 페이지의 html 소스를 가져옴.
# BeautifulSoup으로 html 파싱을 통해 원하는 정보를 추출.

# %%
# 검색 결과가 모두 로딩될 때까지 기다림.
wait = WebDriverWait(driver, 5)
wait.until(EC.presence_of_element_located((By.CLASS_NAME, "quickResultLstCon")))

# 필요한 selenium 작업이 수행된 후, 해당 접속 사이트 url 정보를 가져옴
html = driver.page_source

driver.close()

# html parsing 함
soup = BeautifulSoup(html, "html.parser")

store_list = soup.find_all("li", "quickResultLstCon")
print(store_list[0]["data-lat"])
print(store_list[0]["data-long"])
print(store_list[0]["data-name"])
print(store_list[0].find(class_="result_details").text[:-9])
# Out:
# 37.501087
# 127.043069
# 역삼아레나빌딩
# 서울특별시 강남구 언주로 425 (역삼동)

# %% [markdown]
# ### 자동화 함수 생성

# %%
def get_starbucks_store_search_result_html(url):
    
    # 웹페이지 접속
    driver = webdriver.Chrome(service=Service("../EDA/driver/chromedriver"))
    driver.get(url)
    driver.maximize_window()
    driver.implicitly_wait(3)
    if driver is not None:
        print("웹페이지 접속 완료", "\n")
    
    # [store] 메뉴 > [매장 찾기]의 [지역 검색] 옵션 클릭
    store_menu = driver.find_element(By.CLASS_NAME, "gnb_nav03")
    loca_search_option = driver.find_element(By.CSS_SELECTOR, "#gnb > div > nav > div > ul > li.gnb_nav03 > div > div > div > ul:nth-child(1) > li:nth-child(3) > a")

    action = ActionChains(driver)
    action.move_to_element(store_menu)
    action.move_to_element(loca_search_option)
    action.click().perform()
    
    # [시도] 옵션 리스트 생성 > [서울] 클릭
    wait = WebDriverWait(driver, 10)
    sido_box = wait.until(EC.presence_of_element_located((By.CLASS_NAME, "sido_arae_box")))
    sido_list = sido_box.find_elements(By.TAG_NAME, "li")
    
    wait = WebDriverWait(sido_list[0], 10)
    seoul_option = wait.until(EC.element_to_be_clickable((By.TAG_NAME, "a")))
    seoul_option.click()
    print("[시도] 옵션 리스트 생성 > [서울] 클릭 완료", "\n")
    
    # [구] 옵션 리스트 생성 > [전체] 클릭
    wait = WebDriverWait(driver, 10)
    gu_box = wait.until(EC.presence_of_element_located((By.CLASS_NAME, "gugun_arae_box")))
    gu_list = gu_box.find_elements(By.TAG_NAME, "li")
    
    wait = WebDriverWait(gu_list[0], 10)
    total_gu_option = wait.until(EC.element_to_be_clickable((By.TAG_NAME, "a")))
    total_gu_option.click()
    print("[구] 옵션 리스트 생성 > [전체] 클릭 완료", "\n")
    
    # 검색 결과가 모두 로딩될 때까지 기다림.
    wait = WebDriverWait(driver, 10)
    wait.until(EC.presence_of_element_located((By.CLASS_NAME, "quickResultLstCon")))
    print("검색 결과 모두 로딩 완료", "\n")
    
    # 필요한 selenium 작업이 수행된 후, 해당 접속 사이트 url 정보를 가져옴
    html = driver.page_source
    
    # driver 종료
    driver.close()

    return html


def extract_starbucks_store_info(store):

    # 위도, 경도, 상호, 주소 추출
    latitude = store["data-lat"]
    longtitude = store["data-long"]
    store_name = store["data-name"]
    store_address = store.find(class_="result_details").text[:-9]
    gu = store_address.split(" ")[1]
    brand = "starbucks"
    
    return [brand, store_name, store_address, gu, latitude, longtitude]

# %% [markdown]
# - 데이터프레임 만들지 않고 바로 ```DB```로 보내기
#
#     1. create table starbucks
#     2. insert data into table
#     3. 매장 ```한개씩``` DB 테이블에 저장

# %%
local = mysql.connector.connect(
    host = "localhost",
    port = 3306,
    user = "root",
    password = "1",
    database = "amrbase"
)
cur = local.cursor(buffered=True)

sql = \
    """
    drop table 
    if exists starbucks
    """
cur.execute(sql)

sql = \
    """
    create table starbucks
    (
        brand varchar(16),
        store_name varchar(16),
        address varchar(64),
        gu varchar(16),
        latitude float,
        longtitude float
    )
    """
cur.execute(sql)


# Selenium으로 서울시 전체 스타벅스 매장 검색 결과 출력 작업 수행 완료 후,
# 해당 페이지의 html 소스를 가져옴
url = "https://www.starbucks.co.kr/index.do"
html = get_starbucks_store_search_result_html(url)

# html parsing 함
soup = BeautifulSoup(html, "html.parser")

# 매장 리스트 생성
store_list = soup.find_all("li", "quickResultLstCon")
print("매장 수: ", str(len(store_list)))

for idx, store in tqdm(enumerate(store_list)):
    starbucks_row = extract_starbucks_store_info(store)

    sql = \
    """
    insert into starbucks
    values (%s, %s, %s, %s, %s, %s)
    """
    cur.execute(sql, tuple(starbucks_row))
    print(tuple(starbucks_row))

    local.commit()
    
local.close()
# Out:
# 웹페이지 접속 완료
#
# [시도] 옵션 리스트 생성 > [서울] 클릭 완료
#
# [구] 옵션 리스트 생성 > [전체] 클릭 완료
#
# 검색 결과 모두 로딩 완료
#
# 매장 수:  613
# 0it [00:00, ?it/s]
# ('starbucks', '역삼아레나빌딩', '서울특별시 강남구 언주로 425 (역삼동)', '강남구', '37.501087', '127.043069')
# ('starbucks', '논현역사거리', '서울특별시 강남구 강남대로 538 (논현동)', '강남구', '37.510178', '127.022223')
# ('starbucks', '신사역성일빌딩', '서울특별시 강남구 강남대로 584 (논현동)', '강남구', '37.5139309', '127.0206057')
# ('starbucks', '국기원사거리', '서울특별시 강남구 테헤란로 125 (역삼동)', '강남구', '37.499517', '127.031495')
# ('starbucks', '대치재경빌딩', '서울특별시 강남구 남부순환로 2947 (대치동)', '강남구', '37.494668', '127.062583')
# ('starbucks', '봉은사역', '서울특별시 강남구 봉은사로 619 (삼성동)', '강남구', '37.515000', '127.063196')
# ('starbucks', '압구정윤성빌딩', '서울특별시 강남구 논현로 834 (신사동)', '강남구', '37.5227934', '127.0286009')
# ('starbucks', '코엑스별마당', '서울특별시 강남구 영동대로 513 (삼성동)', '강남구', '37.510150', '127.060275')
# ('starbucks', '삼성역섬유센터R', '서울특별시 강남구 테헤란로 518 (대치동)', '강남구', '37.507750', '127.060651')
# ('starbucks', '압구정R', '서울특별시 강남구 언주로 861 (신사동)', '강남구', '37.5273669', '127.033061')
# ('starbucks', '수서역R', '서울특별시 강남구 광평로 281 (수서동)', '강남구', '37.488008', '127.102650')
# ('starbucks', '양재강남빌딩R', '서울특별시 강남구 남부순환로 2621 (도곡동)', '강남구', '37.485192', '127.036685')
# ('starbucks', '선릉동신빌딩R', '서울특별시 강남구 테헤란로 409 (삼성동)', '강남구', '37.505321', '127.050409')
# ('starbucks', '독산사거리', '서울특별시 금천구 시흥대로 426 (독산동)', '금천구', '37.47158263368701', '126.89860551804541')
# ('starbucks', '금천시흥', '서울특별시 금천구 시흥대로 164 (시흥동)', '금천구', '37.44875938266414', '126.90323875981919')
# ('starbucks', '가산디지털단지역', '서울특별시 금천구 벚꽃로 298 (가산동), 대륭포스트타워 6차 1층', '금천구', '37.48135375445197', '126.88358906045958')
# ('starbucks', '금천독산', '서울특별시 금천구 두산로 70 (독산동)', '금천구', '37.46957081', '126.89565779')
# ('starbucks', '가산디지털', '서울특별시 금천구 가산디지털1로 168 (가산동), 우림라이온스밸리 B동 1층', '금천구', '37.480050688166365', '126.88246896653567')
# ('starbucks', '마리오아울렛', '서울특별시 금천구 벚꽃로 266 마리오아울렛3관', '금천구', '37.47860691180926', '126.88484825777416')
# ('starbucks', '가산브이타워', '서울특별시 금천구 가산디지털1로 128 (가산동), V-TOWER 1층', '금천구', '37.47700409645337', '126.88355058577785')
# ('starbucks', '가산그레이트', '서울특별시 금천구 디지털로9길 32, 갑을그레이트밸리 1층 (가산동)', '금천구', '37.47955080325422', '126.88727191931528')
# ('starbucks', '독산역', '서울특별시 금천구 가산디지털1로 16 (가산동), 107-2, 108, 109호', '금천구', '37.46770966619833', '126.88767404102677')
# ('starbucks', '가산현대아울렛', '서울특별시 금천구 디지털로10길 9 (가산동), 1층 일부', '금천구', '37.477680443', '126.888840553')
# ('starbucks', '가산케이에스', '서울특별시 금천구 벚꽃로36길 30 (가산동), 가산KS타워 1층', '금천구', '37.48089352069766', '126.88515566597013')
# ('starbucks', '월계역', '서울특별시 노원구 초안산로2라길26 월계동(104,105,106호)', '노원구', '37.6295', '127.0574')
# ('starbucks', '월계트레이더스', '서울특별시 노원구 마들로3길 15 (월계동)', '노원구', '37.6277053', '127.06149779999998')
# ('starbucks', '상계초교사거리', '서울특별시 노원구 노원로 449 (상계동)', '노원구', '37.656776', '127.066442')
# ('starbucks', '공릉DT', '서울특별시 노원구 동일로 1015 (공릉동)', '노원구', '37.6206884', '127.0743116')
# ('starbucks', '노원마들역', '서울특별시 노원구 노원로 569 (상계동, 임광아파트)', '노원구', '37.661053011256286', '127.05805507506505')
# ('starbucks', '공릉역', '서울특별시 노원구 동일로 1081 (공릉동)', '노원구', '37.626337', '127.072252')
# ('starbucks', '은행사거리', '서울특별시 노원구 중계로 217, 중흥빌딩 103,203호 (중계동)', '노원구', '37.65048737', '127.0759861')
# ('starbucks', '노원KT', '서울특별시 노원구 노해로 502, (주)KT 노원사옥 (상계동)', '노원구', '37.654562', '127.063617')
# ('starbucks', '광운대', '서울특별시 노원구 석계로 104 (월계동)', '노원구', '37.6231479', '127.06070090000003')
# ('starbucks', '중계역', '서울특별시 노원구 동일로 1339, 대한빌딩 (상계동)', '노원구', '37.64817', '127.062244')
# ('starbucks', '노원역', '서울특별시 노원구 동일로 1413 (상계동) 1층', '노원구', '37.654751', '127.060034')
# ('starbucks', '가든파이브', '서울특별시 송파구 충민로 10 (문정동) 가든파이브툴', '송파구', '37.478280653695684', '127.119331517562')
# ('starbucks', '문정역2번출구', '서울특별시 송파구 문정로 1 (문정동)', '송파구', '37.48629340180307', '127.12320273731552')
# ('starbucks', '잠실본동', '서울특별시 송파구 백제고분로 91 (잠실동), 1층', '송파구', '37.5086445885442', '127.07949103207')
# ('starbucks', '송파NC', '서울특별시 송파구 충민로 66 (문정동)  가든파이브라이프 패션관1층', '송파구', '37.47804418570353', '127.12580079741947')
# ('starbucks', '송파거여역', '서울특별시 송파구 오금로 493 (거여동)', '송파구', '37.49360000716603', '127.14364544756283')
# ('starbucks', '몽촌토성역', '서울특별시 송파구 위례성대로 6 (방이동)', '송파구', '37.516913', '127.113127')
# ('starbucks', '송파KT', '서울특별시 송파구 잠실로 209 (신천동), 오피스빌딩 1층 2~4호', '송파구', '37.5139991', '127.1063026')
# ('starbucks', '문정법조타운 한양타워', '서울특별시 송파구 법원로11길 12 (문정동)', '송파구', '37.485796586165364', '127.11781422446037')
# ('starbucks', '송파마천사거리DT', '서울특별시 송파구 거마로 78 (마천동)', '송파구', '37.499829', '127.147672')
# ('starbucks', '목동파리공원', '서울특별시 양천구 목동동로 377 (목동)', '양천구', '37.535336', '126.878852')
# ('starbucks', '등촌역', '서울특별시 양천구 공항대로 566 (목동) 1층 2층', '양천구', '37.548884', '126.86807')
# ('starbucks', '목동행복한', '서울특별시 양천구 목동동로 309 (목동)', '양천구', '37.52935595865839', '126.87589210780987')
# ('starbucks', '신정DT', '서울특별시 양천구 신월로 341 (신정동)', '양천구', '37.521993', '126.858865')
# ('starbucks', '목동역', '서울특별시 양천구 목동로 203 (신정동) 1층일부', '양천구', '37.526684', '126.863986')
# ('starbucks', '목동오목로', '서울특별시 양천구 오목로 279 (목동) 102,103,104,105호', '양천구', '37.525923', '126.868438')
# ('starbucks', '목동8단지', '서울특별시 양천구 목동서로 299 (신정동)', '양천구', '37.520518', '126.868841')
# ('starbucks', '오목교역', '서울특별시 양천구 오목로 354 (목동)', '양천구', '37.523855929257174', '126.87644987818643')
# ('starbucks', '신월IC DT', '서울특별시 양천구 남부순환로 430 (신월동)', '양천구', '37.529502437956104', '126.83220232277918')
# ('starbucks', '목동7단지', '서울특별시 양천구 목동서로 213 (목동) 세신비젼프라자', '양천구', '37.528012', '126.87053')
# ('starbucks', '목동5단지', '서울특별시 양천구 목동동로 411, 1동 116호(목동, 부영그린타운3차)', '양천구', '37.5363856363692', '126.88211754815594')
# ('starbucks', '목동', '서울특별시 양천구 목동서로 67 (목동) 우성에펠타운', '양천구', '37.53638383', '126.8785597')
# ('starbucks', '현대목동', '서울특별시 양천구 목동동로 257 (목동, 현대하이페리온) 지하2층', '양천구', '37.526848', '126.875023')
# ('starbucks', '목동SBS', '서울특별시 양천구 목동서로 161 (목동), 1/2층 일부', '양천구', '37.52896162444895', '126.87363009594163')
# ('starbucks', '목동트라팰리스', '서울특별시 양천구 오목로 299 (목동)', '양천구', '37.5255', '126.8702')
# ('starbucks', '목동10단지', '서울특별시 양천구 목동서로 401 (신정동, 대림아크로빌), 상가A동 101,101-1호', '양천구', '37.515425616177', '126.859603067999')
# ('starbucks', '신월동DT', '서울특별시 양천구 남부순환로 319 (신월동)', '양천구', '37.5382923530559', '126.827101409243')
# ('starbucks', '타임스퀘어R', '서울특별시 영등포구 영중로 15 지하 1층 (영등포동4가)', '영등포구', '37.51755', '126.90516')
# ('starbucks', '샛강역', '서울특별시 영등포구 여의대방로 376 (여의도동)', '영등포구', '37.5183551', '126.9312716')
# ('starbucks', '영등포역', '서울특별시 영등포구 경인로 870 (영등포동1가)', '영등포구', '37.516999623656375', '126.90906664982087')
# ('starbucks', '당산대로', '서울특별시 영등포구 양평로 22 (당산동6가)', '영등포구', '37.533121', '126.903804')
# ('starbucks', '여의도IFC몰(L1)R', '서울특별시 영등포구 국제금융로 10 (여의도동)  지하1층 178호', '영등포구', '37.524924501336244', '126.92598368412841')
# ('starbucks', '여의도KBS R', '서울특별시 영등포구 의사당대로 26 (여의도동)', '영등포구', '37.526596', '126.918456')
# ('starbucks', '여의도화재보험', '서울특별시 영등포구 국제금융로6길 38 (여의도동)', '영등포구', '37.521345', '126.926004')
# ('starbucks', '국회대로', '서울특별시 영등포구 국회대로 786 (여의도동)', '영등포구', '37.53026', '126.919549')
# ('starbucks', '영등포KT', '서울특별시 영등포구 영중로 119 (영등포동8가)', '영등포구', '37.526419', '126.905314')
# ('starbucks', '여의도공원R', '서울특별시 영등포구 여의공원로 101 (여의도동)', '영등포구', '37.5292850538593', '126.92551269870573')
# ('starbucks', '국회의사당역', '서울특별시 영등포구 의사당대로 8 (여의도동)', '영등포구', '37.52805409993459', '126.91711953333622')
# ('starbucks', '여의도역R', '서울특별시 영등포구 의사당대로 83 (여의도동) 1층', '영등포구', '37.523328', '126.923439')
# ('starbucks', '선유동이레빌딩', '서울특별시 영등포구 선유동2로 57 (양평제1동) 이레빌딩', '영등포구', '37.534277678053385', '126.89697631969191')
# ('starbucks', '동여의도', '서울특별시 영등포구 국제금융로 86 (여의도동) 롯데캐슬 아이비', '영등포구', '37.52063015571123', '126.93168638298105')
# ('starbucks', '여의도ABL타워', '서울특별시 영등포구 의사당대로 147 (여의도동) 알리안츠타워', '영등포구', '37.518749', '126.92779')
# ('starbucks', '영등포신길', '서울특별시 영등포구 신길로 137 (신길동) 1,2층', '영등포구', '37.504566', '126.910073')
# ('starbucks', '문래역', '서울특별시 영등포구 당산로 34 (문래동3가)', '영등포구', '37.517446', '126.895258')
# ('starbucks', '당산', '서울특별시 영등포구 양평로 64 (당산동6가)', '영등포구', '37.535061853441796', '126.89995088868242')
# ('starbucks', '여의도한양증권', '서울특별시 영등포구 국제금융로6길 7 (여의도동) 한양증권', '영등포구', '37.522418', '126.929093')
# ('starbucks', '여의도일신', '서울특별시 영등포구 은행로 11 (여의도동) 1층 1부', '영등포구', '37.52774993247095', '126.92027623791678')
# ('starbucks', '신세계타임스퀘어B2', '서울특별시 영등포구 영중로 9, 신세계타임스퀘어점 리빙관 지하2층 (영등포동4가)', '영등포구', '37.517162', '126.905608')
# ('starbucks', '하이테크시티', '서울특별시 영등포구 경인로 775 (문래동3가) 에이스하이테크시티', '영등포구', '37.51445587278118', '126.89987943038909')
# ('starbucks', '여의도', '서울특별시 영등포구 국제금융로2길 28 (여의도동)', '영등포구', '37.52403519', '126.9245179')
# ('starbucks', '롯데캐슬여의도', '서울특별시 영등포구 의사당대로 127 (여의도동, 롯데캐슬엠파이어) 1층 104호', '영등포구', '37.52025214', '126.9263678')
# ('starbucks', '문래동', '서울특별시 영등포구 선유로 64, 대창타운빌 1층 (문래동3가)', '영등포구', '37.519602', '126.889652')
# ('starbucks', '여의도호성', '서울특별시 영등포구 여의대방로65길 24, 호성빌딩 1층 (여의도동)', '영등포구', '37.52047101976742', '126.92920636135348')
# ('starbucks', '타임스퀘어B2', '서울특별시 영등포구 영중로 15, 지하2층 (영등포동4가)', '영등포구', '37.516810409502995', '126.90336306740143')
# ('starbucks', '영등포본동', '서울특별시 영등포구 영등포로 254 (영등포동3가)', '영등포구', '37.518713', '126.909559')
# ('starbucks', '타임스퀘어2F', '서울특별시 영등포구 영중로 15 지상2층 (영등포동4가)', '영등포구', '37.516922981561166', '126.9033120029923')
# ('starbucks', '여의도의사당', '서울특별시 영등포구 국회대로74길 12 (여의도동)', '영등포구', '37.530023', '126.92109')
# ('starbucks', '여의도IFC(1F)', '서울특별시 영등포구 국제금융로 10 (여의도동)', '영등포구', '37.525273', '126.924668')
# ('starbucks', '여의도교직원공제회', '서울특별시 영등포구 여의나루로 50 (여의도동)', '영등포구', '37.52191490479988', '126.92558789987339')
# ('starbucks', '선유도역 1번출구', '서울특별시 영등포구 양평로 128 (양평동5가)양평로 128', '영등포구', '37.538333', '126.893612')
# ('starbucks', '영등포시장역', '서울특별시 영등포구 영중로 79 (영등포동7가)', '영등포구', '37.52349264546045', '126.90497778447685')
# ('starbucks', '영등포구청역', '서울특별시 영등포구 국회대로 558 ', '영등포구', '37.52789', '126.89608')
# ('starbucks', '서울양평역', '서울특별시 영등포구 선유서로24길 6 (양평동1가, 영등포 중흥 S-CLASS)', '영등포구', '37.523128', '126.885809')
# ('starbucks', '영등포시장교차로', '서울특별시 영등포구 영중로 45 (영등포동6가)', '영등포구', '37.5204239', '126.904446')
# ('starbucks', '더현대서울(B2)R', '서울특별시 영등포구 여의대로 108 (여의도동)', '영등포구', '37.5258834618679', '126.928658229468')
# ('starbucks', '여의도브라이튼', '서울특별시 영등포구 국제금융로 39 (여의도동, 브라이튼 여의도), 1층', '영등포구', '37.5241006226166', '126.929817318958')
# ('starbucks', '여의도TP타워', '서울특별시 영등포구 의사당대로 96 (여의도동)', '영등포구', '37.521624938408046', '126.92302031330276')
# ('starbucks', '당산역사거리', '서울특별시 영등포구 양평로 47 (당산동5가)', '영등포구', '37.53409659351415', '126.90121370080551')
# ('starbucks', '신풍역', '서울특별시 영등포구 신풍로 23 (신길동)', '영등포구', '37.5003469620528', '126.908438384002')
# ('starbucks', '청량리역롯데캐슬스카이', '서울특별시 동대문구 답십리로 27 (전농동, 청량리역 롯데캐슬 SKY-L65)', '동대문구', '37.579249267', '127.045331071')
# ('starbucks', '경동1960', '서울특별시 동대문구 고산자로36길 3 (제기동)', '동대문구', '37.5796141021494', '127.038684963773')
# ('starbucks', '청량리역사', '서울특별시 동대문구 왕산로 214 (전농동) 청량리역사 Connect Place6층', '동대문구', '37.580565324', '127.048564845')
# ('starbucks', '답십리초교사거리', '서울특별시 동대문구 전농로 38 (답십리동)', '동대문구', '37.5682540295405', '127.057240883237')
# ('starbucks', '장안사거리', '서울특별시 동대문구 답십리로 267 (장안동)', '동대문구', '37.5727209002351', '127.070092668638')
# ('starbucks', '서울숲역', '서울특별시 성동구 왕십리로 50 (성수동1가) 1층', '성동구', '37.541868967552624', '127.04489904228212')
# ('starbucks', '금호역', '서울특별시 성동구 동호로 99 (금호동4가)', '성동구', '37.5479939', '127.0153343')
# ('starbucks', '뚝섬역', '서울특별시 성동구 아차산로 42 (성수동1가)', '성동구', '37.546432', '127.049042')
# ('starbucks', '황학사거리', '서울특별시 성동구 왕십리로 410 (하왕십리동, 센트라스)', '성동구', '37.567644', '127.023697')
# ('starbucks', '성수역', '서울특별시 성동구 성수이로 94 (성수동2가)', '성동구', '37.543193', '127.056943')
# ('starbucks', '상왕십리역', '서울특별시 성동구 왕십리로 382 (하왕십리동)', '성동구', '37.5651102845783', '127.028019796271')
# ('starbucks', '왕십리역', '서울특별시 성동구 왕십리로 326 (도선동)', '성동구', '37.5627541', '127.0339072')
# ('starbucks', '한양대', '서울특별시 성동구 왕십리로 225 (행당동) 1,2층', '성동구', '37.55726984', '127.0421649')
# ('starbucks', '엔터식스', '서울특별시 성동구 왕십리광장로 17 (행당동)', '성동구', '37.56175811', '127.0383328')
# ('starbucks', '신금호역', '서울특별시 성동구 금호로 158-1 (금호동1가) 1~5층 전체', '성동구', '37.5549672', '127.0201447')
# ('starbucks', '왕십리역9번출구', '서울특별시 성동구 고산자로 234 (행당동)', '성동구', '37.5605427226347', '127.035267332652')
# ('starbucks', '성수', '서울특별시 성동구 아차산로 104 (성수동2가)', '성동구', '37.5444620830457', '127.055413311106')
# ('starbucks', '옥수', '서울특별시 성동구 독서당로 202 (옥수동)', '성동구', '37.5430298', '127.0133661')
# ('starbucks', '성수낙낙', '서울특별시 성동구 광나루로8길 31 (성수동2가) 성수낙낙 1층 101~107호', '성동구', '37.547326', '127.066367')
# ('starbucks', '효창공원앞역', '서울특별시 용산구 백범로 313 (효창동, 용산 롯데캐슬 센터포레)', '용산구', '37.539305', '126.963060')
# ('starbucks', '서울역서부', '서울특별시 용산구 만리재로 202 (서계동)', '용산구', '37.555165', '126.968446')
# ('starbucks', '이태원역', '서울특별시 용산구 이태원로 188 (이태원동)', '용산구', '37.534273', '126.994789')
# ('starbucks', '한강진역R', '서울특별시 용산구 이태원로 252 (한남동)', '용산구', '37.537131', '127.00098')
# ('starbucks', '용산역써밋R', '서울특별시 용산구 한강대로 69 (한강로2가, 용산푸르지오써밋)', '용산구', '37.527586', '126.965401')
울특별시 중랑구 동일로 952 (묵동, 로프트원 태릉입구역) 1층', '중랑구', '37.615368', '127.076633')
# ('starbucks', '양원역', '서울특별시 중랑구 양원역로10길 3 (망우동)', '중랑구', '37.6066536267232', '127.106359790053')
# ('starbucks', '중화역', '서울특별시 중랑구 봉화산로 35 1층', '중랑구', '37.60170912407773', '127.07841136432036')

# %% [markdown]
# - 서울시 모든 구에 대한 이디야 매장을 검색하기 위해서는 ```서울 __구```로 검색해야함.
# - 따라서 앞에서 생성한 ```starbucks 테이블```로, 위 형태의 ```구 리스트```를 생성

# %%
local = mysql.connector.connect(
    host = "localhost",
    port = 3306,
    user = "root",
    password = "1",
    database = "amrbase"
)
cur = local.cursor(buffered=True)

sql = \
    """
    select concat("서울 ", g.gu) gu
    from (select distinct substring_index(substring_index(address, ' ', 2), ' ', -1) gu 
          from starbucks) g
    """
cur.execute(sql, multi=True)

gu_search_list = []

result = cur.fetchall()
for result_iterrow in result:
    gu_search_list.append(result_iterrow[0])

local.close() 

print(gu_search_list)
# Out:
# ['서울 강남구', '서울 강북구', '서울 강서구', '서울 관악구', '서울 광진구', '서울 금천구', '서울 노원구', '서울 도봉구', '서울 동작구', '서울 마포구', '서울 서대문구', '서울 서초구', '서울 성북구', '서울 송파구', '서울 양천구', '서울 영등포구', '서울 은평구', '서울 종로구', '서울 중구', '서울 강동구', '서울 구로구', '서울 동대문구', '서울 성동구', '서울 용산구', '서울 중랑구']

# %% [markdown]
# ## 2.서울시의 이디야커피 매장 정보를 데이터베이스에 저장

# %% [markdown]
# ### flow check

# %%
url = "https://www.ediya.com/"

driver = webdriver.Chrome(service=Service("../EDA/driver/chromedriver"))
driver.get(url)

driver.maximize_window()
driver.implicitly_wait(3)

if driver is not None:
    print("웹페이지 접속 완료", "\n")
# Out:
# 웹페이지 접속 완료

# %% [markdown]
# - ```매장 찾기``` 메뉴 클릭

# %%
search_store_menu = driver.find_element(By.CLASS_NAME, "store").find_element(By.TAG_NAME, "a")
search_store_menu.click()

# %% [markdown]
# - ```지도```가 다 보일 때까지 스크롤

# %%
map = driver.find_element(By.CLASS_NAME, "store_wrap")
driver.execute_script('arguments[0].scrollIntoView(false);', map)
driver.implicitly_wait(3)

# %% [markdown]
# - ```주소``` 탭 클릭

# %%
search_tab = driver.find_element(By.CLASS_NAME, "store_search_tab")
search_tab_list = search_tab.find_elements(By.TAG_NAME, "li")
search_address_tab = search_tab_list[1]
search_address_tab.click()
driver.implicitly_wait(3)

# %% [markdown]
# - 서울특별시 ```구별``` 검색
#
# >> 검색창에 구 리스트 하나씩 입력하여 검색하기

# %%
search_form = driver.find_element(By.ID, "keyword_div").find_element(By.TAG_NAME, "input")
search_form.send_keys(gu_search_list[0])
search_form.send_keys(Keys.ENTER)

# %% [markdown]
# - 서울특별시 ```구별``` 검색
#
# >> 결과에 따른 매장 정보 추출

# %%
# 검색 결과가 모두 로딩될 때까지 기다림.
wait = WebDriverWait(driver, 10)
wait.until(EC.presence_of_element_located((By.CLASS_NAME, "item")))
print("검색 결과 모두 로딩 완료", "\n")

html = driver.page_source

# html parsing 함
soup = BeautifulSoup(html, "html.parser")

# 매장 리스트 생성
store_list = soup.find_all("li", "item")
print("매장 수: ", str(len(store_list)))
# Out:
# 검색 결과 모두 로딩 완료
#
# 매장 수:  42

# %%
# # Case 1.
# print(store_list[0].find("a")["onclick"])
# print(store_list[0].find("dt").string)
# print(store_list[0].find("dd").string)

# # Case 2.
# print(store_list[1].find("a")["onclick"])
# print(store_list[1].find("dt").string)
# print(store_list[1].find("dd").string)
# Out:
# panLatTo('0','0','0');fnMove();
# 강남YMCA점
# 서울 강남구 논현동
# panLatTo('127.0401601992311','37.51654171724045','1');fnMove();
# 강남구청역아이티웨딩점
# 서울 강남구 학동로 338 (논현동, 강남파라곤)

# %%
# # Case 1.
# text = "panLatTo('0','0','0');fnMove();"
# pattern = r"'\d+.\d+'"
# result = re.findall(pattern, text)
# print(result)
# print(len(result))

# # Case 2.
# text = "panLatTo('127.0401601992311','37.51654171724045','1');fnMove();"
# pattern = r"'\d+.\d+'"
# result = re.findall(pattern, text)
# print(result)
# print(len(result))
# Out:
# []
# 0
# ["'127.0401601992311'", "'37.51654171724045'"]
# 2

# %%
# # 위도, 경도, 상호, 주소 추출
# text = store_list[1].find("a")["onclick"]
# pattern = r"'\d+.\d+'"
# result = re.findall(pattern, text)

# if len(result) == 2:
#     latitude = result[1].replace('\'', '')
#     longtitude = result[0].replace('\'', '')
# else:
#     pass
# store_name = store_list[0].find("dt").string
# store_address = store_list[0].find("dd").string

# [store_name, store_address, latitude, longtitude]
# Out:
# ['강남YMCA점', '서울 강남구 논현동', '37.51654171724045', '127.0401601992311']

# %% [markdown]
# - ```VWord``` 오픈 API를 사용하여 주소를 위도,경도 좌표로 변환

# %%
import pandas as pd
import requests
import json

address = "서울 종로구 종로1가 르메이에르종로타운"

apiurl = "https://api.vworld.kr/req/address?"
params = {
	"service": "address",
	"request": "getcoord",
	"crs": "epsg:4326",
	"address": address,
	"format": "json",
	"type": "road",
	"key": "AE15E29B-29E3-32AA-80C4-EFA6B0E908F6"
}

response = requests.get(apiurl, params=params)
if response.status_code == 200:
	json_data = response.json()
    
lat = json_data.get("response").get("result").get("point").get("y")
lng = json_data.get("response").get("result").get("point").get("x")
print(lat, lng)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[82], line 22
#      19 if response.status_code == 200:
#      20 	json_data = response.json()
# ---> 22 lat = json_data.get("response").get("result").get("point").get("y")
#      23 lng = json_data.get("response").get("result").get("point").get("x")
#      24 print(lat, lng)
#
# AttributeError: 'NoneType' object has no attribute 'get'

# %%
html_per_gu = []

for idx, gu in enumerate(gu_search_list):

    search_form = driver.find_element(By.ID, "keyword_div").find_element(By.TAG_NAME, "input")
    search_form.send_keys(gu)
    search_form.send_keys(Keys.ENTER)
    
    # 검색 결과가 모두 로딩될 때까지 기다림.
    wait = WebDriverWait(driver, 10)
    wait.until(EC.presence_of_element_located((By.CLASS_NAME, "item")))

    html = driver.page_source
    html_per_gu.append(html)
    
    search_form.clear()
    driver.implicitly_wait(3)


for idx, html in enumerate(html_per_gu):
    # html parsing 함
    soup = BeautifulSoup(html, "html.parser")

    # 매장 리스트 생성
    store_list = soup.find_all("li", "item")
    print(str(idx), ". 매장 수: ", str(len(store_list)))
# Out:
# 0 . 매장 수:  42
# 1 . 매장 수:  42
# 2 . 매장 수:  16
# 3 . 매장 수:  43
# 4 . 매장 수:  27
# 5 . 매장 수:  20
# 6 . 매장 수:  21
# 7 . 매장 수:  31
# 8 . 매장 수:  22
# 9 . 매장 수:  24
# 10 . 매장 수:  36
# 11 . 매장 수:  23
# 12 . 매장 수:  28
# 13 . 매장 수:  28
# 14 . 매장 수:  31
# 15 . 매장 수:  26
# 16 . 매장 수:  35
# 17 . 매장 수:  29
# 18 . 매장 수:  35
# 19 . 매장 수:  34
# 20 . 매장 수:  28
# 21 . 매장 수:  25
# 22 . 매장 수:  23
# 23 . 매장 수:  21
# 24 . 매장 수:  13

# %%
text = "서울 광진구 능동로 92 (자양동, 스타시티몰) 지하 2층 201호"
pattern = r"\s\([^)]+\)"
result = re.findall(pattern, text)
print(text.split(result[0])[0])

address = "서울 서초구 방배로 234 우신빌딩"
address = " ".join(address.split(" ")[:-1])
print(address)
# Out:
# 서울 광진구 능동로 92
# 서울 서초구 방배로 234

# %% [markdown]
# ### 자동화 함수 생성

# %%
def get_ediya_store_search_result_html(url):
    
    # 웹페이지 접속
    driver = webdriver.Chrome(service=Service("../EDA/driver/chromedriver"))
    driver.get(url)
    driver.maximize_window()
    driver.implicitly_wait(3)
    if driver is not None:
        print("웹페이지 접속 완료", "\n")
    
    # [매장 찾기] 메뉴 클릭
    search_store_menu = driver.find_element(By.CLASS_NAME, "store").find_element(By.TAG_NAME, "a")
    search_store_menu.click()
    
    # [지도]가 다 보일 때까지 스크롤
    map = driver.find_element(By.CLASS_NAME, "store_wrap")
    driver.execute_script('arguments[0].scrollIntoView(false);', map)
    driver.implicitly_wait(3)
    
    # [주소] 탭 클릭
    search_tab = driver.find_element(By.CLASS_NAME, "store_search_tab")
    search_tab_list = search_tab.find_elements(By.TAG_NAME, "li")
    search_address_tab = search_tab_list[1]
    search_address_tab.click()
    driver.implicitly_wait(3)
    
    # 서울특별시 [구별] 검색 > 구별 html 리스트 생성
    html_per_gu = []
    for idx, gu in enumerate(gu_search_list):

        search_form = driver.find_element(By.ID, "keyword_div").find_element(By.TAG_NAME, "input")
        search_form.send_keys(gu)
        search_form.send_keys(Keys.ENTER)
        
        # 검색 결과가 모두 로딩될 때까지 기다림.
        wait = WebDriverWait(driver, 10)
        wait.until(EC.presence_of_element_located((By.CLASS_NAME, "item")))
        
        time.sleep(0.2)

        # 필요한 selenium 작업이 수행된 후, 해당 접속 사이트 url 정보를 가져옴
        html = driver.page_source
        html_per_gu.append(html)
        
        # 검색창 초기화
        search_form.clear()
        driver.implicitly_wait(3)
        
    print(str(idx+1), "개의 구 가져오기 완료")

    # driver 종료
    driver.close()

    return html_per_gu


def extract_ediya_store_info(store):

    brand = "ediya"
    store_name = store.find("dt").string
    store_address = store.find("dd").string
    gu = store_address.split(" ")[1]
    
    try:
        latitude, longtitude = vworld_geocoding(store_address)
    except:
        try:
            text = store_address
            pattern = r"\([^)]+\)"
            result = re.findall(pattern, text)
            store_address = text.split(result[0])[0]
        except:
            store_address = " ".join(store_address.split(" ")[:-1])
        
        crd = geopy_geocoding(store_address)
        latitude = crd['lat']
        longtitude = crd['lng']

    return [brand, store_name, store_address, gu, latitude, longtitude] 


def vworld_geocoding(address):
    apiurl = "https://api.vworld.kr/req/address?"
    params = {
        "service": "address",
        "request": "getcoord",
        "crs": "epsg:4326",
        "address": address,
        "format": "json",
        "type": "road",
        "key": "AE15E29B-29E3-32AA-80C4-EFA6B0E908F6"
    }

    response = requests.get(apiurl, params=params)
    if response.status_code == 200:
        json_data = response.json()
        
    lat = json_data.get("response").get("result").get("point").get("y")
    lng = json_data.get("response").get("result").get("point").get("x")
    
    return lat, lng


from geopy.geocoders import Nominatim
def geopy_geocoding(address):
    geolocoder = Nominatim(user_agent = 'South Korea', timeout=None)
    geo = geolocoder.geocode(address)
    crd = {"lat": str(geo.latitude), "lng": str(geo.longitude)}

    return crd

# %% [markdown]
# - 데이터프레임 만들지 않고 바로 ```DB```로 보내기
#
#     1. create table ediya
#     2. insert data into table
#     3. 매장 ```한개씩``` DB 테이블에 저장

# %%
local = mysql.connector.connect(
    host = "localhost",
    port = 3306,
    user = "root",
    password = "1",
    database = "amrbase"
)
cur = local.cursor(buffered=True)

sql = \
    """
    drop table 
    if exists ediya
    """
cur.execute(sql)

sql = \
    """
    create table ediya
    (
        brand varchar(16),
        store_name varchar(16),
        address varchar(64),
        gu varchar(16),
        latitude float,
        longtitude float
    )
    """
cur.execute(sql)


# Selenium으로 서울시 전체 스타벅스 매장 검색 결과 출력 작업 수행 완료 후,
# 해당 페이지의 html 소스를 가져옴
url = "https://www.ediya.com/"
html_per_gu = get_ediya_store_search_result_html(url)

for idx, html in tqdm(enumerate(html_per_gu)):

    soup = BeautifulSoup(html, "html.parser")

    # 매장 리스트 생성
    store_list = soup.find_all("li", "item")
    print(str(idx), ". 매장 수: ", str(len(store_list)))

    for idx, store in enumerate(store_list):
        ediay_row = extract_ediya_store_info(store)

        sql = \
        """
        insert into ediya
        values (%s, %s, %s, %s, %s, %s)
        """
        cur.execute(sql, tuple(ediay_row))
        print(tuple(ediay_row))

        local.commit()

local.close()
# Out:
# 웹페이지 접속 완료
#
# 25 개의 구 가져오기 완료
# 0it [00:00, ?it/s]
# 0 . 매장 수:  42
# ('ediya', '강남YMCA점', '서울 강남구 논현동', '강남구', '37.505859315', '127.025582227')
# ('ediya', '강남구청역아이티웨딩점', '서울 강남구 학동로 338 (논현동, 강남파라곤)', '강남구', '37.516457676', '127.040705402')
# ('ediya', '강남논현학동점', '서울 강남구 논현로131길 28 (논현동)', '강남구', '37.514072116', '127.028103964')
# ('ediya', '강남대치점', '서울 강남구 역삼로 415 (대치동, 성진빌딩)', '강남구', '37.501286858', '127.052396046')
# ('ediya', '강남도산점', '서울 강남구 도산대로37길 20 (신사동)', '강남구', '37.522263365', '127.031497239')
# ('ediya', '강남세곡점', '서울 강남구 헌릉로569길 9 (세곡동, 강남지웰파인즈)', '강남구', '37.466788871', '127.100777587')
# ('ediya', '금천롯데마트점', '서울 금천구 시흥대로 291 (독산동, 금천롯데캐슬골드파크3차)', '금천구', '37.459972328', '126.896532162')
# ('ediya', '독산동쌈지공원점', '서울 금천구 독산로 276 (독산동)', '금천구', '37.471349944', '126.903287624')
# ('ediya', '독산동점', '서울 금천구 독산로 218 (독산동, 창영빌딩)', '금천구', '37.466383268', '126.902008073')
# ('ediya', '박미삼거리점', '서울 금천구 시흥대로 150 (시흥동)', '금천구', '37.447628328', '126.903663309')
# ('ediya', '석수푸르지오점', '서울 금천구 삼성산길 11 (시흥동, 위너스타워)', '금천구', '37.434128570', '126.904824589')
# ('ediya', '세광교회점', '서울 금천구 독산로 124 (시흥동)', '금천구', '37.458367510', '126.905548404')
# ('ediya', '시흥동점', '서울 금천구 시흥동', '금천구', '37.456902661', '126.895367606')
# ('ediya', '시흥사거리점', '서울 금천구 시흥대로63길 8 (시흥동)', '금천구', '37.455063232', '126.899092256')
# ('ediya', '시흥유통센터점', '서울 금천구 시흥대로 88 (시흥동, 오복빌딩)', '금천구', '37.441889818', '126.903909593')
# ('ediya', '시흥중앙점', '서울 금천구 금하로 748 (시흥동)', '금천구', '37.449947069', '126.912722617')
# ('ediya', '에이스가산포휴점', '서울 금천구 가산디지털1로 225 (가산동, 에이스 가산 포휴(지식산업센터))', '금천구', '37.485072516', '126.878884504')
# ('ediya', '은행나무사거리점', '서울 금천구 금하로 690 (시흥동)', '금천구', '37.451809949', '126.906623882')
# 6 . 매장 수:  31
# ('ediya', '공릉역점', '서울 노원구 동일로192길 5 (공릉동)', '노원구', '37.626075277', '127.073390480')
# ('ediya', '공릉중앙점', '서울 노원구 공릉로 146 (공릉동)', '노원구', '37.623086821', '127.079536789')
# ('ediya', '광운대점', '서울 노원구 광운로 29 (월계동)', '노원구', '37.620323569', '127.058425796')
# ('ediya', '노원KT점', '서울 노원구 노해로 494 (상계동)', '노원구', '37.654527097', '127.063084744')
# ('ediya', '노원사거리점', '서울 노원구 동일로 1393 (상계동)', '노원구', '37.652944583', '127.060550897')
# ('ediya', '노원역2호점', '서울 노원구 상계로 64 (상계동)', '노원구', '37.655785340', '127.062269733')
# ('ediya', '노원중앙점', '서울 노원구 노원로 452 (상계동)', '노원구', '37.656812166', '127.066903542')
# ('ediya', '당고개역점', '서울 노원구 상계로 313 (상계동)', '노원구', '37.670807683', '127.080369965')
# ('ediya', '마들역점', '서울 노원구 동일로 1541 (상계동)', '노원구', '37.666154188', '127.057135477')
# ('ediya', '상계동점', '서울 노원구 한글비석로52길 8 (상계동)', '노원구', '37.664884644', '127.066474736')
# ('ediya', '상계상록스토아점', '서울 노원구 동일로227길 26 (상계동, 상계주공15단지아파트)', '노원구', '37.667525850', '127.054086723')
# ('ediya', '상계역사거리점', '서울 노원구 한글비석로 409 (상계동) 1~2층', '노원구', '37.661146805', '127.070853182')
# ('ediya', '상계역점', '서울 노원구 덕릉로 698 (중계동)', '노원구', '37.659846781', '127.075654228')
# ('ediya', '상계중앙점', '서울 노원구 동일로 1650 (상계동)', '노원구', '37.675483840', '127.055546853')
# ('ediya', '상도역점', '서울 동작구 상도로 277 (상도1동)', '동작구', '37.502815322', '126.948341129')
# ('ediya', '상도중앙점', '서울 동작구 만양로 17 (상도동)', '동작구', '37.506293990', '126.947133278')
# ('ediya', '상도파크엘점', '서울 동작구 양녕로 220 (상도동, 상도역 롯데캐슬 파크엘)', '동작구', '37.501452627', '126.946229503')
# ('ediya', '숭실대점', '서울 동작구 사당로 2 (상도동)', '동작구', '37.495473900', '126.954693609')
# ('ediya', '신대방삼거리점', '서울 동작구 상도로 78 (대방동)', '동작구', '37.499542293', '126.929147275')
# ('ediya', '신상도초교점', '서울 동작구 양녕로 183 (상도동)', '동작구', '37.497723281', '126.943162558')
# ('ediya', '이수중앙점', '서울 동작구 사당로 285 (사당동)', '동작구', '37.484654152', '126.979184663')
# ('ediya', '중앙대점', '서울 동작구 흑석로 79 (흑석동)', '동작구', '37.507039494', '126.958411519')
# ('ediya', '중앙대후문점', '서울 동작구 흑석로 20 (상도동)', '동작구', '37.504828039', '126.953031630')
# ('ediya', '총신대입구역점', '서울 동작구 동작대로 119-1 (사당동)', '동작구', '37.487378451', '126.981877552')
# ('ediya', '총신대점', '서울 동작구 사당로16가길 96 (사당동) 1,2층', '동작구', '37.485117938', '126.968823388')
# ('ediya', '해군회관점', '서울 동작구 여의대방로 194 (대방동)', '동작구', '37.504250129', '126.922259753')
# ('ediya', '흑석역점', '서울 동작구 현충로 100-1 (흑석동)', '동작구', '37.507603404', '126.964755711')
# 9 . 매장 수:  36
# ('ediya', '공덕롯데캐슬점', '서울 마포구 마포대로 109 (공덕동, 롯데캐슬프레지던트)', '마포구', '37.545068654', '126.950847496')
# ('ediya', '대흥역점', '서울 마포구 백범로 100 ', '마포구', '37.5486691', '126.9402282')
# ('ediya', '동교중앙점', '서울 마포구 동교로27길 8 (동교동)', '마포구', '37.558785076', '126.923047414')
# ('ediya', '마포공덕역점', '서울 마포구 새창로 6 (도화동)', '마포구', '37.542046706', '126.950507942')
# ('ediya', '마포구청점', '서울 마포구 월드컵로 196 (성산동)', '마포구', '37.564800394', '126.902751832')
# ('ediya', '마포데시앙점', '서울 마포구 독막로 320 (도화동)', '마포구', '37.542965165', '126.947873255')
# ('ediya', '마포성산시영점', '서울 마포구 월드컵북로 210 (성산동)', '마포구', '37.569218170', '126.905802995')
# ('ediya', '마포점', '서울 마포구 도화길 10 (도화동)', '마포구', '37.539807372', '126.947408042')
# ('ediya', '망리단길점', '서울 마포구 포은로 81-1 (망원동, S-빌딩)', '마포구', '37.554313617', '126.905265758')
# ('ediya', '망원역점', '서울 마포구 월드컵로 82-1 (서교동)', '마포구', '37.556376387', '126.910226947')
# ('ediya', '망원중앙점', '서울 마포구 월드컵로 147 (망원동)', '마포구', '37.560794549', '126.905472846')
# ('ediya', '상수역점', '서울 마포구 와우산로 41-1 (상수동)', '마포구', '37.548233408', '126.922824882')
# ('ediya', '상암DMC점', '서울 마포구 월드컵북로 396 (상암동)', '마포구', '37.579428847', '126.889782088')
# ('ediya', '명지대점', '서울 서대문구 거북골로 35 (남가좌동)', '서대문구', '37.579394779', '126.923924989')
# ('ediya', '명지전문대점', '서울 서대문구 가좌로 140 (홍은동)', '서대문구', '37.584544975', '126.924170279')
# ('ediya', '무악재역점', '서울 서대문구 홍제동 ', '서대문구', '37.583377040', '126.938056109')
# ('ediya', '북가좌동점', '서울 서대문구 증가로 257 (북가좌동)', '서대문구', '37.583463343', '126.911532120')
# ('ediya', '서대문구청점', '서울 서대문구 연희로 237 (연희동)', '서대문구', '37.578252286', '126.935688639')
# ('ediya', '서대문점', '서울 서대문구 냉천동', '서대문구', '37.566242892', '126.964828433')
# ('ediya', '신촌기차역점', '서울 서대문구 신촌역로 35 (창천동)', '서대문구', '37.558976198', '126.941459646')
# ('ediya', '신촌역점', '서울 서대문구 신촌로 87-20 (창천동)', '서대문구', '37.556424807', '126.936423580')
# ('ediya', '아현역점', '서울 서대문구 신촌로37길 10 (북아현동, 아현 메디컬)', '서대문구', '37.557665472', '126.957137841')
# ('ediya', '연남동점', '서울 서대문구 연희로 42 (연희동)', '서대문구', '37.562354006', '126.927851085')
# ('ediya', '연대서문점', '서울 서대문구 연희로10길 86 (연희동)', '서대문구', '37.563694361', '126.933693269')
# ('ediya', '연세대점', '서울 서대문구 연세로12길 10 (창천동)', '서대문구', '37.558854147', '126.937532186')
# ('ediya', '연세의료원ABMRC점', '서울 서대문구 연세로 50-1 (신촌동, 세브란스병원)', '서대문구', '37.562026376', '126.941220295')
# ('ediya', '연세의료원제중관점', '서울 서대문구 연세로 50-1 (신촌동, 세브란스병원)', '서대문구', '37.562026376', '126.941220295')
# ('ediya', '연세의료원종합관점', '서울 서대문구 연세로 50-1 (신촌동, 세브란스병원)', '서대문구', '37.562026376', '126.941220295')
# ('ediya', '연희삼거리점', '서울 서대문구 연희로 117 (연희동)', '서대문구', '37.568314991', '126.931832536')
# ('ediya', '연희홍연길점', '서울 서대문구 홍제천로 146-9 (연희동)', '서대문구', '37.576381434', '126.930025020')
# ('ediya', '충정로3가점', '서울 서대문구 경기대로 26-26 (충정로3가, 더스타일하우스디센트럴)', '서대문구', '37.560995459', '126.962198483')
# ('ediya', '홍은사거리점', '서울 서대문구 통일로 510 (홍은동, 북한산 더샵)', '서대문구', '37.594561513', '126.941177323')
# ('ediya', '홍제역점', '서울 서대문구 홍제동', '서대문구', '37.583377040', '126.938056109')
# 11 . 매장 수:  28
# ('ediya', '강남센트럴시티점', '서울 서초구 신반포로 176 (반포동, 센트럴시티)', '서초구', '37.504281262', '127.004566674')
# ('ediya', '교대역점', '서울 서초구 서초대로56길 22 (서초동, 성운빌딩)', '서초구', '37.493484446', '127.017109183')
# ('ediya', '국립국악원점', '서울 서초구 남부순환로 2364 (서초동, 국립국악원)', '서초구', '37.477718844', '127.009818517')
# ('ediya', '국립중앙도서관디지털관점', '서울 서초구 반포대로 201 (반포동, 국립중앙도서관)', '서초구', '37.497888577', '127.003767303')
# ('ediya', '신월7동점', '서울 양천구 지양로 79 (신월동)', '양천구', '37.522425743', '126.832998093')
# ('ediya', '신월사거리점', '서울 양천구 남부순환로 353 (신월동)', '양천구', '37.535661682', '126.828931292')
# ('ediya', '신월신곡시장점', '서울 양천구 신월로 172 (신월동)', '양천구', '37.518312212', '126.842651164')
# ('ediya', '신정네거리역점', '서울 양천구 중앙로 282 (신정동)', '양천구', '37.521553591', '126.852578501')
# ('ediya', '신정서부점', '서울 양천구 신정로11길 50-15 (신정동)', '양천구', '37.512244872', '126.838316145')
# ('ediya', '신정역점', '서울 양천구 오목로 155 (신정동)', '양천구', '37.524965959', '126.854654087')
# ('ediya', '양천구청점', '서울 양천구 목동동로 63 (신정동)', '양천구', '37.515315577', '126.862312301')
# ('ediya', '오목교대학학원점', '서울 양천구 오목로 319 (목동)', '양천구', '37.525077214', '126.873065680')
# ('ediya', '오목교역점', '서울 양천구 신목로 102 (목동)', '양천구', '37.523612108', '126.875780185')
# 15 . 매장 수:  35
# ('ediya', 'KBS별관점', '서울 영등포구 국제금융로8길 27-9 (여의도동, 동북빌딩)', '영등포구', '37.519672012', '126.928931919')
# ('ediya', '국회의사당역점', '서울 영등포구 의사당대로 22 (여의도동, 이룸센터)', '영등포구', '37.526870069', '126.917843125')
# ('ediya', '남부고용센터점', '서울 영등포구 양산로 71 (양평동3가)', '영등포구', '37.525033081', '126.891102910')
# ('ediya', '당산버드나루점', '서울 영등포구 버드나루로 87 (영등포동7가)', '영등포구', '37.525949116', '126.908727261')
# ('ediya', '당산역점', '서울 영등포구 당산로 222 (당산동5가, 당산디오빌)', '영등포구', '37.533238564', '126.902282870')
# ('ediya', '당산중앙점', '서울 영등포구 당산로 159 (당산동4가)', '영등포구', '37.528838177', '126.897565958')
# ('ediya', '대림1동점', '서울 영등포구 도림로 198 (대림동)', '영등포구', '37.496428453', '126.902823605')
# ('ediya', '대림3동점', '서울 영등포구 대림로 212 (대림동)', '영등포구', '37.499545961', '126.898161237')
# ('ediya', '대림역점', '서울 영등포구 도림로31길 2 (대림동)', '영등포구', '37.492533975', '126.895915471')
# ('ediya', '도림사거리점', '서울 영등포구 도림로 326 (신길동)', '영등포구', '37.506610142', '126.901812004')
# ('ediya', '도림점', '서울 영등포구 도신로15길 40 (도림동, 도림빌딩)', '영등포구', '37.508619314', '126.896580258')
# ('ediya', '라이프점', '서울 영등포구 63로 40 (여의도동, 라이프오피스텔)', '영등포구', '37.519616962', '126.939168736')
# ('ediya', '보라매역점', '서울 영등포구 여의대방로 141 (신길동)', '영등포구', '37.499705409', '126.919942191')
# ('ediya', '서여의도점', '서울 영등포구 국회대로72길 4 (여의도동, 아이비피아빌딩)', '영등포구', '37.530334211', '126.919916443')
# ('ediya', '선유도역점', '서울 영등포구 양평로 126 (양평동5가)', '영등포구', '37.538249023', '126.893950204')
# ('ediya', '신길성애병원점', '서울 영등포구 여의대방로53길 27 (신길동)', '영등포구', '37.511889690', '126.921556241')
# ('ediya', '신길썬프라자점', '서울 영등포구 신길로 42 (신길동)', '영등포구', '37.496482727', '126.908619801')
# ('ediya', '신길아이파크점', '서울 영등포구 도림로 280 (신길동)', '영등포구', '37.502940595', '126.904213818')
# ('ediya', '신길역점', '서울 영등포구 영등포로 353 (신길동)', '영등포구', '37.515044300', '126.918106718')
# ('ediya', '신길중앙점', '서울 영등포구 도신로 229 (신길동)', '영등포구', '37.512228836', '126.916490894')
# ('ediya', '양평동2가점', '서울 영등포구 선유서로25길 19 (양평동2가, 오목교투웨니퍼스트)', '영등포구', '37.524507041', '126.883937953')
# ('ediya', '여의나루역점', '서울 영등포구 여의나루로 113 (여의도동)', '영등포구', '37.526054641', '126.930769623')
# ('ediya', '여의도농협재단점', '서울 영등포구 국제금융로8길 2 (여의도동, 농협재단빌딩)', '영등포구', '37.522017307', '126.930048017')
# ('ediya', '여의도역점', '서울 영등포구 의사당대로 108 (여의도동, 아일렉스)', '영등포구', '37.521016624', '126.923988061')
# ('ediya', '영등포knk점', '서울 영등포구 영신로 220 (영등포동8가, KnK디지털타워)', '영등포구', '37.526807751', '126.904248128')
# ('ediya', '영등포그랜드점', '서울 영등포구 양산로9길 15 (양평동3가, 그랜드타워)', '영등포구', '37.526776414', '126.888590563')
# ('ediya', '영등포시장점', '서울 영등포구 영등포로35길 19 ', '영등포구', '37.52148', '126.9043777')
# ('ediya', '영등포아크로타워점', '서울 영등포구 국회대로54길 10 (영등포동7가, 아크로타워 스퀘어)', '영등포구', '37.524058575', '126.907462701')
# ('ediya', '영등포에이스점', '서울 영등포구 경인로 775 (문래동3가)', '영등포구', '37.515051811', '126.898618877')
# ('ediya', '영등포점', '서울 영등포구 영중로 16-1 (영등포동3가)', '영등포구', '37.517903362', '126.906196149')
# ('ediya', '영등포코레일점', '서울 영등포구 경인로 846 (영등포동, 영등포 민자역사)', '영등포구', '37.515625906', '126.907526384')
# ('ediya', '영등포홈플러스점', '서울 영등포구 당산로 42 (문래동3가, 홈플러스)', '영등포구', '37.518318836', '126.895947884')
# ('ediya', '한강성심병원점', '서울 영등포구 버드나루로 51 (영등포동2가)', '영등포구', '37.523088486', '126.910596590')
# ('ediya', '한국수출입은행점', '서울 영등포구 은행로 38 (여의도동, 한국수출입은행빌딩)', '영등포구', '37.528634331', '126.923406212')
# ('ediya', '힐스테이트클래시안점', '서울 영등포구 신길로28길 9 (신길동, 힐스테이트 클래시안)', '영등포구', '37.503319126', '126.910985938')
# 16 . 매장 수:  29
# ('ediya', '갈현점', '서울 은평구 갈현로 268 (갈현동)', '은평구', '37.620747832', '126.916752111')
# ('ediya', '구산사거리점', '서울 은평구 서오릉로 195 ', '은평구', '37.6087609', '126.9199545')
# ('ediya', '구산역점', '서울 은평구 연서로 148 (대조동)', '은평구', '37.611997676', '126.917623535')
# ('ediya', '구파발역점', '서울 은평구 진관2로 29-21 (진관동, 드림스퀘어)', '은평구', '37.635786771', '126.919351496')
# ('ediya', '녹번동점', '서울 은평구 진흥로 156 (녹번동, 신명빌딩)', '은평구', '37.608752215', '126.926975194')
# ('ediya', '정동점', '서울 중구 정동길 2-1 (정동)', '중구', '37.567971393', '126.969337438')
# ('ediya', '중림브라운스톤점', '서울 중구 청파로 464 (중림동, 브라운스톤서울)', '중구', '37.560781726', '126.968243320')
# ('ediya', '중림점', '서울 중구 청파로 464 (중림동)', '중구', '37.560781726', '126.968243320')
# ('ediya', '충무로3가점', '서울 중구 퇴계로27길 31 (충무로3가)', '중구', '37.562555672', '126.991244353')
# ('ediya', '충무로점', '서울 중구 퇴계로 188 (필동1가)', '중구', '37.560834133', '126.992554130')
# ('ediya', '충무아트홀점', '서울 중구 퇴계로 381-1 (신당동)', '중구', '37.565278025', '127.013998217')
# ('ediya', '충무필동점', '서울 중구 퇴계로 218-5 (필동2가)', '중구', '37.561380269', '126.996296576')
# ('ediya', '충정로역점', '서울 중구 중림로 10 (중림동, 중림동 삼성 사이버 빌리지)', '중구', '37.558700452', '126.964559807')
# ('ediya', '태평로점', '서울 중구 세종대로11길 26 (서소문동)', '중구', '37.562324655', '126.974441130')
# ('ediya', '퇴계로2길점', '서울 중구 퇴계로2길 1 (남창동)', '중구', '37.557578962', '126.977410340')
# ('ediya', '한국은행점', '서울 중구 남대문로 29-2 (남대문로3가)', '중구', '37.561443690', '126.978964215')
# ('ediya', '황학롯데캐슬점', '서울 중구 청계천로 400 (황학동, 롯데캐슬베네치아)', '중구', '37.570745415', '127.019843132')
# ('ediya', '회현SK리더스점', '서울 중구 퇴계로 72 (회현동1가, 리더스뷰남산)', '중구', '37.559180003', '126.980547246')
# 19 . 매장 수:  28
# ('ediya', '강동고덕교차로점', '서울 강동구 고덕로 421 (강일동, 대한연세요양원)', '강동구', '37.557391129', '127.172574958')
# ('ediya', '강동구청점', '서울 강동구 성내로6길 20 (성내동, 청일 베르네)', '강동구', '37.528889206', '127.122370420')
# ('ediya', '강동성내점', '서울 강동구 풍성로 162 (성내동)', '강동구', '37.530525512', '127.129878043')
# ('ediya', '강동신명초교점', '서울 강동구 명일로 260 (길동, 길동신동아아파트)', '강동구', '37.541591276', '127.147499915')
# ('ediya', '강동역점', '서울 강동구 천호대로 1065 (천호동, 강동상떼빌)', '강동구', '37.537038084', '127.130465976')
# ('ediya', '강일점', '서울 강동구 아리수로93길 19 (강일동, 임페리얼타워)', '강동구', '37.565379061', '127.174117043')
# ('ediya', '고덕강일2지구점', '서울 강동구 아리수로93나길 76 (강일동)', '강동구', '37.572472402', '127.175933645')
# ('ediya', '고덕그라시움후문점', '서울 강동구 동남로82길 121 (고덕동)', '강동구', '37.560403457', '127.163705001')
# ('ediya', '고덕래미안힐스점', '서울 강동구 아리수로50길 50 (고덕동, 래미안힐스테이트고덕)', '강동구', '37.559121551', '127.150902812')
# ('ediya', '고덕점', '서울 강동구 동남로75길 19 (명일동, 명일빌딩)', '강동구', '37.554127418', '127.155177494')
# ('ediya', '굽은다리역점', '서울 강동구 양재대로 1543 (천호동)', '강동구', '37.543478528', '127.141854478')
# ('ediya', '서울시립대점', '서울 동대문구 서울시립대로 164 (전농동, 도석프라자)', '동대문구', '37.583296727', '127.054838766')
# ('ediya', '신설동역점', '서울 동대문구 천호대로 11-3 (신설동)', '동대문구', '37.575046760', '127.024930235')
# ('ediya', '용두동사거리점', '서울 동대문구 왕산로 68 (용두동)', '동대문구', '37.577498813', '127.030924003')
# ('ediya', '용두동점', '서울 동대문구 고산자로 413-1 (용두동)', '동대문구', '37.576660557', '127.037933425')
# ('ediya', '이문점 ', '서울 동대문구 신이문로 19 (이문동)', '동대문구', '37.603129445', '127.064250190')
# ('ediya', '장안동사거리점', '서울 동대문구 답십리로 309 (장안동)', '동대문구', '37.572380193', '127.074740607')
# ('ediya', '장안동점', '서울 동대문구 장한로 43 (장안동)', '동대문구', '37.565073868', '127.066708003')
# ('ediya', '장안중랑천점', '서울 동대문구 장한로18길 32 (장안동)', '동대문구', '37.567495177', '127.070789189')
# ('ediya', '장안중앙점', '서울 동대문구 사가정로25길 42 (장안동)', '동대문구', '37.580687990', '127.070976723')
# ('ediya', '장한평군자초교점', '서울 동대문구 한천로2길 53 (장안동)', '동대문구', '37.562842460', '127.061409218')
# ('ediya', '전농뉴타운점', '서울 동대문구 답십리로 77 (전농동)', '동대문구', '37.575124805', '127.049528447')
# ('ediya', '전농사거리점', '서울 동대문구 사가정로 132 (전농동)', '동대문구', '37.577597160', '127.059524936')
# ('ediya', '청량리점', '서울 동대문구 왕산로 225 (청량리동)', '동대문구', '37.581927263', '127.046997571')
# ('ediya', '촬영소사거리점', '서울 동대문구 답십리로 264 (장안동)', '동대문구', '37.572220214', '127.069540225')
# ('ediya', '회기역중앙점', '서울 동대문구 회기로 194-1 (휘경동)', '동대문구', '37.589833058', '127.057496486')
# 22 . 매장 수:  21
# ('ediya', '논골사거리점', '서울 성동구 난계로 35 (금호동1가)', '성동구', '37.555512101', '127.024478206')
# ('ediya', '뚝섬역점', '서울 성동구 상원길 38-1 (성수동1가)', '성동구', '37.547397097', '127.048714448')
# ('ediya', '마장동점', '서울 성동구 고산자로 339-2 (마장동)', '성동구', '37.570020579', '127.037356698')
# ('ediya', '마장역점', '서울 성동구 마장로 293-1 (마장동)', '성동구', '37.565947882', '127.042195062')
# ('ediya', '상왕십리역점', '서울 성동구 무학봉15길 27 (하왕십리동)', '성동구', '37.563706551', '127.030189267')
# ('ediya', '서울숲역점', '서울 성동구 왕십리로 96-1 (성수동1가)', '성동구', '37.546294437', '127.044886177')
# ('ediya', '성동구청점', '서울 성동구 고산자로 269 (도선동)', '성동구', '37.563699539', '127.035771212')
# ('ediya', '성수2가점', '서울 성동구 성덕정길 106 (성수동2가)', '성동구', '37.537163122', '127.055093107')
# ('ediya', '성수아카데미점', '서울 성동구 성수이로 118 (성수동2가)', '성동구', '37.545102651', '127.057833513')
# ('ediya', '성수우리W타워점', '서울 성동구 아차산로15길 19 (성수동2가)', '성동구', '37.544750776', '127.062069603')
# ('ediya', '성수중앙점', '서울 성동구 성수일로6길 47 (성수동2가, 현성빌딩)', '성동구', '37.544307042', '127.055244365')
# ('ediya', '신금호역점', '서울 성동구 금호산길 64 (금호동2가)', '성동구', '37.553891606', '127.019621703')
# ('ediya', '옥수동점', '서울 성동구 매봉길 12 (옥수동)', '성동구', '37.545285013', '127.015699128')
# ('ediya', '옥수역점', '서울 성동구 한림말5길 9 (옥수동)', '성동구', '37.542012060', '127.016716619')
# ('ediya', '왕십리비트플렉스점', '서울 성동구 왕십리광장로 17 (행당동)', '성동구', '37.561467686', '127.038344508')
# ('ediya', '왕십리센트라스점', '서울 성동구 무학로 22 (홍익동)', '성동구', '37.566052258', '127.030308741')
# ('ediya', '왕십리역점', '서울 성동구 왕십리로 309 (행당동)', '성동구', '37.561439888', '127.034699828')
# ('ediya', '응봉동점', '서울 성동구 독서당로 381 (응봉동, 현대종합상가)', '성동구', '37.550211785', '127.030720599')
# ('ediya', '장한평역점', '서울 성동구 천호대로 426 (용답동)', '성동구', '37.560816181', '127.066255055')
# ('ediya', '텐즈힐점', '서울 성동구 무학로 33 (하왕십리동, 텐즈힐)', '성동구', '37.567352753', '127.029524480')
# ('ediya', '행당동점', '서울 성동구 고산자로 201 (행당동)', '성동구', '37.558053566', '127.033764237')
# 23 . 매장 수:  13
# ('ediya', 'IBK고객센터점', '서울 용산구 한남대로 72 (한남동, IBK기업은행고객센터)', '용산구', '37.535069278', '127.007053603')
# ('ediya', '동부이촌동점', '서울 용산구 이촌로77길 19 (이촌동)', '용산구', '37.520553722', '126.974666988')
# ('ediya', '동자동점', '서울 용산구 후암로 93 (동자동)', '용산구', '37.553352783', '126.975117493')
# ('ediya', '삼각지점', '서울 용산구 한강대로 138 (한강로2가)', '용산구', '37.531441683', '126.970465341')
# ('ediya', '숙대입구역점', '서울 용산구 한강대로 289 (갈월동)', '용산구', '37.544053761', '126.971964072')
# ('ediya', '순천향병원점', '서울 용산구 대사관로 72 ', '용산구', '37.533097699', '127.005945701')
# ('ediya', '용문점', '서울 용산구 원효로41길 73 (원효로2가)', '용산구', '37.535849473', '126.961137968')
# ('ediya', '용산원효점', '서울 용산구 원효로 70 (원효로4가, 신정빌딩)', '용산구', '37.532505502', '126.951642145')
# ('ediya', '용산청파점', '서울 용산구 청파로71길 10 (청파동1가, 새마을금고)', '용산구', '37.549465318', '126.969410121')
# ('ediya', '용산효창점', '서울 용산구 효창원로66길 2 (효창동)', '용산구', '37.540566009', '126.962195078')
# ('ediya', '용산후암점', '서울 용산구 후암로 40-2 (후암동, 성원빌딩)', '용산구', '37.549523185', '126.977713358')
# ('ediya', '원효로점', '서울 용산구 원효로 257 (원효로1가)', '용산구', '37.540571129', '126.969116624')
# ('ediya', '이태원역점', '서울 용산구 이태원로 176 (이태원동)', '용산구', '37.534269338', '126.993426268')
# 24 . 매장 수:  30
# ('ediya', '금란망우점', '서울 중랑구 망우로 460 (망우동)', '중랑구', '37.600106371', '127.103136686')
# ('ediya', '동원사거리점', '서울 중랑구 겸재로 240 (면목동, 행복오피스텔)', '중랑구', '37.589626202', '127.094127480')
# ('ediya', '망우동점', '서울 중랑구 망우로 416 (망우동)', '중랑구', '37.599164884', '127.098350887')
# ('ediya', '망우중앙점', '서울 중랑구 용마산로115길 109 (망우동, 한일써너스빌리젠시2단지)', '중랑구', '37.597806897', '127.094550608')
# ('ediya', '망우코레일점', '서울 중랑구 망우로55길 11-10 (상봉동, 망우역)', '중랑구', '37.600035532', '127.094415727')
# ('ediya', '먹골역점', '서울 중랑구 동일로157길 13 (묵동)', '중랑구', '37.609739839', '127.076896618')
# ('ediya', '면목경남아너스빌점', '서울 중랑구 면목로27길 92 (면목동)', '중랑구', '37.574266678', '127.080518408')
# ('ediya', '면목늘찬병원점', '서울 중랑구 동일로 643 (면목동, 늘찬병원)', '중랑구', '37.587990888', '127.079680838')
# ('ediya', '면목본동점', '서울 중랑구 면목로 370 (면목동)', '중랑구', '37.584948879', '127.088545012')
# ('ediya', '면목역점', '서울 중랑구 면목로 429 (면목동, 킴스아파트)', '중랑구', '37.590180709', '127.086861239')
# ('ediya', '묵동자이점', '서울 중랑구 동일로 932 (묵동, 묵동자이아파트)', '중랑구', '37.613655763', '127.077532593')
# ('ediya', '봉화산역점', '서울 중랑구 신내로 211 (신내동)', '중랑구', '37.616431175', '127.092621776')
# ('ediya', '사가정아이파크점', '서울 중랑구 동일로92길 57 (면목동, 메디포레)', '중랑구', '37.583472376', '127.083186723')
# ('ediya', '사가정역점', '서울 중랑구 면목로 325 (면목동)', '중랑구', '37.581137984', '127.088173498')
# ('ediya', '상봉엠코점', '서울 중랑구 망우로 353 (상봉동, 상봉 프레미어스 엠코)', '중랑구', '37.597951233', '127.090090871')
# ('ediya', '상봉역점', '서울 중랑구 망우로 277 (상봉동)', '중랑구', '37.596054709', '127.083420859')
# ('ediya', '상봉중앙점', '서울 중랑구 망우로 316 (상봉동)', '중랑구', '37.596515268', '127.087610379')
# ('ediya', '서울상봉1동점', '서울 중랑구 상봉중앙로 36 (상봉동)', '중랑구', '37.600284353', '127.087796839')
# ('ediya', '서울중랑경찰서점', '서울 중랑구 신내역로3길 40-11 (신내동)', '중랑구', '37.617713153', '127.104792327')
# ('ediya', '서울중화초등학교점', '서울 중랑구 신내로7가길 7 (신내동, 제이리옴)', '중랑구', '37.602337278', '127.095447445')
# ('ediya', '서일중앙점', '서울 중랑구 용마산로 394 (면목동, 해동검도)', '중랑구', '37.586651866', '127.095551300')
# ('ediya', '신내동점', '서울 중랑구 봉화산로 215 (신내동)', '중랑구', '37.607656113', '127.096544472')
# ('ediya', '양원남부점', '서울 중랑구 양원역로 25-10 (망우동)', '중랑구', '37.603130023', '127.107376615')
# ('ediya', '양원역점', '서울 중랑구 양원역로14가길 24 (망우동)', '중랑구', '37.607408628', '127.106775439')
# ('ediya', '용마산역점', '서울 중랑구 면목로 254-1 (면목동)', '중랑구', '37.575434778', '127.085692292')
# ('ediya', '중랑교차로점', '서울 중랑구 동일로 683 (면목동)', '중랑구', '37.591433138', '127.079862259')
# ('ediya', '중랑역점', '서울 중랑구 망우로 198 (상봉동)', '중랑구', '37.593172975', '127.074893419')
# ('ediya', '중화동점', '서울 중랑구 동일로129길 1 (중화동)', '중랑구', '37.599400052', '127.079550670')
# ('ediya', '중화역점', '서울 중랑구 동일로 815, 1층', '중랑구', '37.603130614', '127.078891517')
# ('ediya', '화랑대역점', '서울 중랑구 신내로25가길 2 (묵동, 현동학당)', '중랑구', '37.619484679', '127.084187156')

# %% [markdown]
# ## 3. 데이터 시각화

# %% [markdown]
# 1. 각 브랜드별 구별 매장 개수 시각화

# %%
local = mysql.connector.connect(
    host = "localhost",
    port = 3306,
    user = "root",
    password = "1",
    database = "amrbase"
)

cur = local.cursor(buffered=True)

sql = \
    """
    select *
    from (select brand, gu, count(gu) count
        from starbucks
        group by brand, gu) s
    union
    select *
    from (select brand, gu, count(gu) count
        from ediya
        group by brand, gu) e
    """

each_brand_count_df = pd.read_sql(sql, con=local)
local.close()

display(each_brand_count_df.head())
# Out:
# /tmp/ipykernel_5267/2997013541.py:24: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   each_brand_count_df = pd.read_sql(sql, con=local)
#        brand   gu  count
# 0  starbucks  강남구     91
# 1  starbucks  강북구      6
# 2  starbucks  강서구     28
# 3  starbucks  관악구     12
# 4  starbucks  광진구     19

# %%
colors = ["#59886B", "#4646CD"]
sns.set_palette(sns.color_palette(colors))

plt.figure(figsize=(12, 8))
sns.barplot(x="gu", y="count", hue="brand", data=each_brand_count_df)
plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# >> 스타벅스 매장은 강남구에 밀집되어 있고, 이디야 매장은 구 전체에 고르게 분포하는 양상을 보임.

# %% [markdown]
# 2. folium으로 지도 시각화

# %%
local = mysql.connector.connect(
    host = "localhost",
    port = 3306,
    user = "root",
    password = "1",
    database = "amrbase"
)

cur = local.cursor(buffered=True)

sql = \
    """
    select latitude, longtitude
    from starbucks
    """
s_map_df = pd.read_sql(sql, con=local)

sql = \
    """
    select latitude, longtitude
    from ediya
    """
e_map_df = pd.read_sql(sql, con=local)

local.close()

display(s_map_df.head())
display(e_map_df.head())
# Out:
# /tmp/ipykernel_5267/3873676969.py:16: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   s_map_df = pd.read_sql(sql, con=local)
# /tmp/ipykernel_5267/3873676969.py:23: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   e_map_df = pd.read_sql(sql, con=local)
#    latitude  longtitude
# 0   37.5011     127.043
# 1   37.5102     127.022
# 2   37.5139     127.021
# 3   37.4995     127.031
# 4   37.4947     127.063
#    latitude  longtitude
# 0   37.5059     127.026
# 1   37.5165     127.041
# 2   37.5141     127.028
# 3   37.5013     127.052
# 4   37.5223     127.031

# %%
geo_path = "../EDA/data/02. skorea_municipalities_geo_simple.json"
geo_str = json.load(open(geo_path, encoding="utf-8"))

tiles = "https://tiles.stadiamaps.com/tiles/stamen_toner/{z}/{x}/{y}{r}.png?api_key=c2cc2e93-c5d1-4f4c-9250-843d23b7da20"
attr = "toner"

my_map = folium.Map(location=(37.5502, 126.982), zoom_start=12, tiles=tiles, attr=attr)
setting = folium.Choropleth(geo_data=geo_str,
                            key_on="feature.id",
                            fill_color="lightyellow")
setting.add_to(my_map)

for idx, rows in s_map_df.iterrows():
    folium.CircleMarker(location=[rows["latitude"], rows["longtitude"]],
                  radius=5,
                  color="darkgreen",
                  fill_color="darkgreen").add_to(my_map)
    
for idx, rows in e_map_df.iterrows():
    folium.CircleMarker(location=[rows["latitude"], rows["longtitude"]],
                  radius=4,
                  color="middleblue",
                  fill_color="blue",
                  fill_opacity=50).add_to(my_map)

    
my_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_c6d1160fca2239886fc697ea45598242 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_c6d1160fca2239886fc697ea45598242&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_c6d1160fca2239886fc697ea45598242 = L.map(
#                 &quot;map_c6d1160fca2239886fc697ea45598242&quot;,
#                 {
#                     center: [37.5502, 126.982],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 12,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_c46b29d9c895f546c8100aea49bb8e91 = L.tileLayer(
#                 &quot;https://tiles.stadiamaps.com/tiles/stamen_toner/{z}/{x}/{y}{r}.png?api_key=c2cc2e93-c5d1-4f4c-9250-843d23b7da20&quot;,
#                 {&quot;attribution&quot;: &quot;toner&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_c46b29d9c895f546c8100aea49bb8e91.addTo(map_c6d1160fca2239886fc697ea45598242);
#
#
#             var choropleth_896879d990f79359b66266c2cdf892a8 = L.featureGroup(
#                 {}
#             );
#
#
#         function geo_json_92e7e3c0191be430220032ab39ae052b_styler(feature) {
#             switch(feature.id) {
#                 default:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;fillColor&quot;: &quot;lightyellow&quot;, &quot;fillOpacity&quot;: 0.6, &quot;opacity&quot;: 1, &quot;weight&quot;: 1};
#             }
#         }
#
#         function geo_json_92e7e3c0191be430220032ab39ae052b_onEachFeature(feature, layer) {
#             layer.on({
#             });
#         };
#         var geo_json_92e7e3c0191be430220032ab39ae052b = L.geoJson(null, {
#                 onEachFeature: geo_json_92e7e3c0191be430220032ab39ae052b_onEachFeature,
#
#                 style: geo_json_92e7e3c0191be430220032ab39ae052b_styler,
#         });
#
#         function geo_json_92e7e3c0191be430220032ab39ae052b_add (data) {
#             geo_json_92e7e3c0191be430220032ab39ae052b
#                 .addData(data);
#         }
#             geo_json_92e7e3c0191be430220032ab39ae052b_add({&quot;features&quot;: [{&quot;geometry&quot;: {&quot;coordinates&quot;: [[[127.11519584981606, 37.557533180704915], [127.16683184366129, 37.57672487388627], [127.18408792330152, 37.55814280369575], [127.16530984307447, 37.54221851258693], [127.14672806823502, 37.51415680680291], [127.12123165719615, 37.52528270089], [127.1116764203608, 37.540669955324965], [127.11519584981606, 37.557533180704915]]], &quot;type&quot;: &quot;Polygon&quot;}, &quot;id&quot;: &quot;\uac15\ub3d9\uad6c&quot;, &quot;properties&quot;: {&quot;base_year&quot;: &quot;2013&quot;, &quot;code&quot;: &quot;11250&quot;, &quot;name&quot;: &quot;\uac15\ub3d9\uad6c&quot;, &quot;name_eng&quot;: &quot;Gangdong-gu&quot;}, &quot;type&quot;: &quot;Feature&quot;}, {&quot;geometry&quot;: {&quot;coordinates&quot;: [[[127.0690698130372, 37.522279423505026], [127.10087519791962, 37.524841220167055], [127.1116764203608, 37.540669955324965], [127.12123165719615, 37.52528270089], [127.14672806823502, 37.51415680680291], [127.1634944215765, 37.497445406097484], [127.14206058413274, 37.47089819098501], [127.12440571080893, 37.46240445587048], [127.11117085201238, 37.485708381512445], [127.0719146000724, 37.50224013587669], [127.0690698130372, 37.522279423505026]]], &quot;type&quot;: &quot;Polygon&quot;}, &quot;id&quot;: &quot;\uc1a1\ud30c\uad6c&quot;, &quot;properties&quot;: {&quot;base_year&quot;: &quot;2013&quot;, &quot;code&quot;: &quot;11240&quot;, &quot;name&quot;: &quot;\uc1a1\ud30c\uad6c&quot;, &quot;name_eng&quot;: &quot;Songpa-gu&quot;}, &quot;type&quot;: &quot;Feature&quot;}, {&quot;geometry&quot;: {&quot;coordinates&quot;: [[[127.05867359288398, 37.52629974922568], [127.0690698130372, 37.522279423505026], [127.0719146000724, 37.50224013587669], [127.11117085201238, 37.485708381512445], [127.12440571080893, 37.46240445587048], [127.09842759318751, 37.45862253857461], [127.08640440578156, 37.472697935184655], [127.0559170481904, 37.4659228914077], [127.03621915098798, 37.48175802427603], [127.01397119667513, 37.52503988289669], [127.02302831890559, 37.53231899582663], [127.05867359288398, 37.52629974922568]]], &quot;type&quot;: &quot;Polygon&quot;}, &quot;id&quot;: &quot;\uac15\ub0a8\uad6c&quot;, &quot;properties&quot;: {&quot;base_year&quot;: &quot;2013&quot;, &quot;code&quot;: &quot;11230&quot;, &quot;name&quot;: &quot;\uac15\ub0a8\uad6c&quot;, &quot;name_eng&quot;: &quot;Gangnam-gu&quot;}, &quot;type&quot;: &quot;Feature&quot;}, {&quot;geometry&quot;: {&quot;coordinates&quot;: [[[127.01397119667513, 37.52503988289669], [127.03621915098798, 37.48175802427603], [127.0559170481904, 37.4659228914077], [127.08640440578156, 37.472697935184655], [127.09842759318751, 37.45862253857461], [127.09046928565951, 37.44296826114185], [127.06778107605433, 37.426197424057314], [127.04957232987142, 37.42805836845694], [127.03881782597922, 37.45382039851715], [126.99072073195462, 37.455326143310025], [126.98367668291802, 37.473856492692086], [126.98223807916081, 37.509314966770326], [127.01397119667513, 37.52503988289669]]], &quot;type&quot;: &quot;Polygon&quot;}, &quot;id&quot;: &quot;\uc11c\ucd08\uad6c&

# %% [markdown]
# 3. 위도 및 경도 좌표를 미터 거리로 변환 (거리 m)

# %%
local = mysql.connector.connect(
    host = "localhost",
    port = 3306,
    user = "root",
    password = "1",
    database = "amrbase"
)
cur = local.cursor(buffered=True)

# === starbucks location table ======================== #
sql = \
    """
    drop table 
    if exists s_locations
    """
cur.execute(sql)

sql = \
    """
    CREATE TABLE s_locations 
    (
        id INT AUTO_INCREMENT PRIMARY KEY,
        name VARCHAR(255),
        coordinates POINT
    )
    """
cur.execute(sql)

sql = \
    """
    insert into s_locations (name, coordinates) 
        SELECT store_name, point(longtitude, latitude) 
        from starbucks
    """
cur.execute(sql)

# === ediya location table ========================== #
sql = \
    """
    drop table 
    if exists e_locations
    """
cur.execute(sql)

sql = \
    """
    CREATE TABLE e_locations 
    (
        id INT AUTO_INCREMENT PRIMARY KEY,
        name VARCHAR(255),
        coordinates POINT
    )
    """
cur.execute(sql)

sql = \
    """
    insert into e_locations (name, coordinates) 
        SELECT store_name, point(longtitude, latitude) 
        from ediya
    """
cur.execute(sql)

local.commit()
local.close()

# %%
local = mysql.connector.connect(
    host = "localhost",
    port = 3306,
    user = "root",
    password = "1",
    database = "amrbase"
)
cur = local.cursor(buffered=True)

sql = \
    """
    drop table 
    if exists stores_distance
    """
cur.execute(sql)

sql = \
    """
    CREATE TABLE stores_distance 
    (
        s_id INT,
        e_id INT,
        distance_in_meters float
    )
    """
cur.execute(sql)
            
sql = \
    """
    insert into stores_distance (s_id, e_id, distance_in_meters)
    select *
    from (SELECT
            s_id,
            e_id,
            round(ST_Distance_Sphere(coordinates1, coordinates2), 3) AS distance_in_meters
          FROM (SELECT
                    l1.id AS s_id,
                    l2.id AS e_id,
                    l1.coordinates AS coordinates1,
                    l2.coordinates AS coordinates2
                FROM
                    s_locations l1,
                    e_locations l2) AS distances  
          ) stores_distance
    """
cur.execute(sql)

local.commit()
local.close()

# %%
local = mysql.connector.connect(
    host = "localhost",
    port = 3306,
    user = "root",
    password = "1",
    database = "amrbase"
)
cur = local.cursor(buffered=True)
            
sql = \
    """
    select s_id, count(e_id) 
    from stores_distance 
    where distance_in_meters<=500 
    group by s_id
    order by s_id
    """
ediya_from_starbucks_in_500 = pd.read_sql(sql, con=local)

sql = \
    """
    select e_id, count(s_id) 
    from stores_distance 
    where distance_in_meters<=500 
    group by e_id
    order by e_id
    """
starbucks_from_ediya_in_500 = pd.read_sql(sql, con=local)

local.close()

display(ediya_from_starbucks_in_500.head())
display(starbucks_from_ediya_in_500.head())
# Out:
# /tmp/ipykernel_5267/73495876.py:18: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   ediya_from_starbucks_in_500 = pd.read_sql(sql, con=local)
# /tmp/ipykernel_5267/73495876.py:28: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   starbucks_from_ediya_in_500 = pd.read_sql(sql, con=local)
#    s_id  count(e_id)
# 0     1            1
# 1     2            1
# 2     3            3
# 3     4            2
# 4     5            1
#    e_id  count(s_id)
# 0     1            6
# 1     2            2
# 2     3            2
# 3     4            5
# 4     5            5

# %%
print(ediya_from_starbucks_in_500.mean()[1])
print(starbucks_from_ediya_in_500.mean()[1])
# Out:
# 2.6137184115523464
# 2.9917355371900825

# %% [markdown]
# >> 스타벅스 각 매장에 대하여 500m 안에 존재하는 이디야 매장의 수의 평균은 2.6137184115523464
# >> 이디야 각 매장에 대하여 500m 안에 존재하는 스타벅스 매장의 수의 평균은 2.9917355371900825

# %%
from folium.plugins import HeatMap

my_map_1 = folium.Map(location=(37.5502, 126.982), zoom_start=12, tiles=tiles, attr=attr)
654, 127.084], [37.559, 127.081], [37.4808, 126.881], [37.4795, 126.887], [37.4747, 126.882], [37.4756, 126.893], [37.4804, 126.884], [37.4767, 126.886], [37.4789, 126.89], [37.4787, 126.879], [37.4688, 126.887], [37.46, 126.897], [37.4714, 126.903], [37.4664, 126.902], [37.4476, 126.904], [37.4341, 126.905], [37.4584, 126.906], [37.4569, 126.895], [37.4551, 126.899], [37.4419, 126.904], [37.4499, 126.913], [37.4851, 126.879], [37.4518, 126.907], [37.6261, 127.073], [37.6231, 127.08], [37.6203, 127.058], [37.6545, 127.063], [37.6529, 127.061], [37.6558, 127.062], [37.6568, 127.067], [37.6708, 127.08], [37.6662, 127.057], [37.6649, 127.066], [37.6675, 127.054], [37.6611, 127.071], [37.6598, 127.076], [37.6755, 127.056], [37.6283, 127.078], [37.622, 127.087], [37.6156, 127.064], [37.6366, 127.069], [37.6791, 127.055], [37.6269, 127.08], [37.6266, 127.062], [37.6298, 127.059], [37.6504, 127.078], [37.6473, 127.074], [37.6499, 127.083], [37.6399, 127.064], [37.6408, 127.068], [37.6521, 127.072], [37.6196, 127.078], [37.6403, 127.073], [37.6359, 127.071],

# %% [markdown]
# - 브랜드별 매장 분포도 시각화

# %%
plt.figure(figsize=(12, 8))
sns.lineplot(x="gu", y="count", hue="brand", data=each_brand_count_df)
plt.xticks(rotation=45)

s = each_brand_count_df[each_brand_count_df['brand'] == "starbucks"]
plt.fill_between(s['gu'], s['count'], color="lightgreen", alpha=0.4)

e = each_brand_count_df[each_brand_count_df['brand'] == "ediya"]
plt.fill_between(e['gu'], e['count'], color="lightblue", alpha=0.4)

plt.show()

# %% [markdown]
# >> starbucks 매장은 서울 중심부, 특히 중구와 강남구에 집중적으로 분포되어 있다.
# >> 반면, ediya 매장은 서울 지역에 고르게 분포되어 있지만, starbucks 매장 분포와 마찬가지로, 중구와 강남구에 집중되어 있다.

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(12, 8))
plt.scatter("longtitude", "latitude",
            data=s_map_df,
            cmap="green")
plt.scatter("longtitude", "latitude",
            data=e_map_df,
            cmap="blue")
plt.xlabel("longtitude")
plt.ylabel("latitude")
plt.colorbar()
plt.show()
# Out:
# /tmp/ipykernel_12410/3642150714.py:4: UserWarning: No data for colormapping provided via 'c'. Parameters 'cmap' will be ignored
#   plt.scatter("longtitude", "latitude",
# /tmp/ipykernel_12410/3642150714.py:7: UserWarning: No data for colormapping provided via 'c'. Parameters 'cmap' will be ignored
#   plt.scatter("longtitude", "latitude",

# %%
plt.figure(figsize=(12, 8))
sns.displot(s_map_df, x="longtitude", y="latitude", palette="green")
sns.displot(e_map_df, x="longtitude", y="latitude", palette="blue")
plt.show()
# Out:
# /tmp/ipykernel_28361/704285821.py:2: UserWarning: Ignoring `palette` because no `hue` variable has been assigned.
#   sns.displot(s_map_df, x="longtitude", y="latitude", palette="green")
# /tmp/ipykernel_28361/704285821.py:3: UserWarning: Ignoring `palette` because no `hue` variable has been assigned.
#   sns.displot(e_map_df, x="longtitude", y="latitude", palette="blue")

# %% [markdown]
# >> 시각화로 분석해본 결과,
# >> 서울시 스타벅스 매장과 이디야 매장의 분포가 다를 뿐더러
# >> 각 매장에 대한 500m 반경 안에 존재하는 상대 브랜드 매장 수의 평균도 스타벅스 보다 이디야가 더 크므로,
# >> '이디야는 스타벅스 매장이 위치시키는 곳에 위치시킨다.'라고 보기는 어렵다.
